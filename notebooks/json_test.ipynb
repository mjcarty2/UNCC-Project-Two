# %%
import json

# %%
states_json = "../static/js/us_states.geojson"

# %%
with open(states_json) as f:
        data = json.load(f)

# %%
data
# Out:
# {'type': 'FeatureCollection',
#  'name': 'us_states',
#  'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4269'}},
#  'features': [{'type': 'Feature',
#    'properties': {'REGION': '3',
#     'DIVISION': '5',
#     'STATEFP': '54',
#     'STATENS': '01779805',
#     'GEOID': '54',
#     'STUSPS': 'WV',
#     'NAME': 'West Virginia',
#     'LSAD': '00',
#     'MTFCC': 'G4000',
#     'FUNCSTAT': 'A',
#     'ALAND': 62266474513,
#     'AWATER': 489028543,
#     'INTPTLAT': '+38.6472854',
#     'INTPTLON': '-080.6183274'},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-81.747254, 39.095379],
#        [-81.746354, 39.096578],
#        [-81.746254, 39.096878],
#        [-81.746054, 39.096978],
#        [-81.745854, 39.097278],
#        [-81.745754, 39.097478],
#        [-81.745554, 39.097978],
#        [-81.745454, 39.098078],
#        [-81.745354, 39.098478],
#        [-81.745254, 39.098878],
#        [-81.745154, 39.099378],
# ...

# %%
type(data)
# Out:
# dict
